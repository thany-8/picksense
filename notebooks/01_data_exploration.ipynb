# %% [markdown]
# # PickSense — Data Exploration
#
# In this notebook, I explore the Jacquard robotic grasp dataset.
#
# The goal is to understand:
# - what one object image looks like
# - how grasp annotations are stored
# - what information describes a robotic grasp
# - how the grasp position relates to the image
#
# No model training is performed in this notebook.

# %%
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
